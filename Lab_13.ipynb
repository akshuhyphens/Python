# %%
discount_fare = lambda fare: fare - 200

# %%
def square(a):
  sq = a * a
  return sq

print(square(5))
# Out:
# 25

# %%
sq = lambda a,b: a*b
print(sq(5,2))
# Out:
# 10

# %%
print("Discounted Fare :", discount_fare(2500))
# Out:
# Discounted Fare : 2300

# %%
ticket_fares = [2500, 1800, 3200]

updated_fares = list(
    map(
        lambda fare: fare + 100,
        ticket_fares
    )
)

print(updated_fares)
# Out:
# [2600, 1900, 3300]

# %%
print(updated_fares)
# Out:
# [2600, 1900, 3300]

# %%
reservation_status = [
   "Confirmed",
   "Waiting",
   "Confirmed",
   "RAC"]

# %%
confirmed_tickets = list(
   filter(
       lambda status: status == "Confirmed",
       reservation_status))

# %%
print(confirmed_tickets)
# Out:
# ['Confirmed', 'Confirmed']

# %%
passengers = [
   "Rahul Sharma",
   "Priya Singh",
   "Amit Verma"]

seats = [
   "B1-21",
   "B1-22",
   "B1-23"]

# %%
reservation_data = list(
   zip(passengers, seats))

# %%
print(reservation_data)
# Out:
# [('Rahul Sharma', 'B1-21'), ('Priya Singh', 'B1-22'), ('Amit Verma', 'B1-23')]

# %%
passenger_list = [
   "Rahul Sharma",
   "Priya Singh",
   "Amit Verma"]

# %%
for index, passenger in enumerate(passenger_list):
   print(index, passenger)
# Out:
# 0 Rahul Sharma
# 1 Priya Singh
# 2 Amit Verma

# %%
ticket_fares = [2500,800,3200,600]

# %%
valid_fares = list(
    filter(
        lambda fare:fare > 1000,
        ticket_fares))

# %%
ticket_fares = [2400, 3200]
final_fares =list(
    map(
        lambda fare: fare + 100,
        valid_fares))
print(final_fares)
# Out:
# [2600, 3300]

# %%
passengers = ["Rahul", "Priya", "Amit"]
seats = ["S1", "S2", "S3"]
fares = [2500, 1800, 3200]

# %%
reservation_date = list(
    zip(passengers,seats, fares))

# %%
print("===================================")
print(" Railway Reservation Report ")
print("===================================")

for index, data in enumerate(reservation_date):
    passenger, seat, fare = data

    final_fare = (lambda x: x - 100)(fare)

    print("Reservation ID :", index + 1)
    print("Passenger :", passenger)
    print("Seat :", seat)
    print("Final Fare :", final_fare)
    print("-----------------------------------")
# Out:
# ===================================
#  Railway Reservation Report
# ===================================
# Reservation ID : 1
# Passenger : Rahul
# Seat : S1
# Final Fare : 2400
# -----------------------------------
# Reservation ID : 2
# Passenger : Priya
# Seat : S2
# Final Fare : 1700
# -----------------------------------
# Reservation ID : 3
# Passenger : Amit
# Seat : S3
# Final Fare : 3100
# -----------------------------------
